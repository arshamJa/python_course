# %% [markdown]
# ### What we're going to cover:
# * Reading / writing files
# * CSV
# * JSON

# %% [markdown]
# > **Opening a File**
# >
# > To open a file, we can use `open()` function, which requires file-path and mode as arguments.

# %%
f = open("files/open.txt")
print(f)
# Out:
# <_io.TextIOWrapper name='files/open.txt' mode='r' encoding='cp1252'>

# %% [markdown]
# > To read the file we use `read()` function

# %%
print(f.read())
# Out:
# Hi. Wellcome to python programming language. Some other dummy text

# %% [markdown]
# > **Closing a File**
# >
# > `file.close()` method closes the file and releases the system resources. If the file was opened in write or append mode, closing ensures that all changes are properly saved.

# %%
file = open("files/open.txt", 'r')
content = file.read()
print(content)
file.close()
# Out:
# Hi. Wellcome to python programming language. Some other dummy text

# %% [markdown]
# > **Reading Files:** python provides several methods to read data from a file:
# >
# > * `read()` - Reads the entire file or a specified number of characters.
# >
# > * `readline()` - Reads a single line from the file.
# >
# > * `readlines()` - Reads all lines from the file and returns them as a list.

# %%
# Reading the entire file
file = open('files/example.txt', 'r')
content = file.read()
print(content)
file.close()

# Reading the first 10 characters
file = open('files/example.txt', 'r')
content = file.read(10)
print(content)
file.close()

# Reading a single line
file = open('files/example.txt', 'r')
line = file.readline()
print(line)
file.close()

# Reading all lines
file = open('files/example.txt', 'r')
lines = file.readlines()
print(lines)
file.close()
# Out:
# Hello, World!This line is appended.
# Hello, Wor
# Hello, World!This line is appended.
# ['Hello, World!This line is appended.']

# %% [markdown]
# > **Writing to Files:** writing data to a file in Python can be done using the write() and writelines() methods:
# >
# > * `write()` - Writes a string to the file.
# >
# > * `writelines()` - Writes a list of strings to the file.

# %%
# Writing a string to a file
file = open('files/example_write.txt', 'w')
file.write('Hello, world!')
file.close()

# Writing a list of strings to a file
lines = ['Hello, world!', 'Python is great!', 'File handling is easy.']
file = open('files/example_write.txt', 'w')
file.writelines(lines)
file.close()

# %% [markdown]
# > Using **with Statement:**
# >
# >Instead of manually opening and closing the file, you can use the with statement, which <ins>automatically handles closing.</ins> This reduces the risk of file corruption and resource leakage.
# >
# > The mode parameter specifies the mode in which the file is opened. Common modes include:
# > * `r` file is opened in **read** mode.
# > * `w` file is opened in **write** mode.
# > * `a` file is opened in **append** mode.

# %%
# Reading the entire file content
with open("files/open.txt", "r") as file:
    content = file.read()
    print(content) # File closes automatically
# Out:
# Hi. Wellcome to python programming language. Some other dummy text

# %%
# Reading line by line
with open("files/open.txt", "r") as file:
    for line in file:
        print(line)
# Out:
# Hi. Wellcome to python programming language. Some other dummy text

# %%
# Writing a string to a file
with open("files/example.txt", "w") as file:
    file.write("Hello, World!")

# %%
with open("files/geek.txt", "w") as file:
    file.write("Hello, Python!\n")
    file.write("File handling is easy with Python.")

print("File written successfully")
# Out:
# File written successfully

# %%
# Writing multiple lines to a file
lines = ["Line 1", "Line 2", "Line 3"]
with open("files/example2.txt", "w") as file:
    for line in lines:
        file.write(line + "\n")

# %%
# Appending to an existing file
with open("files/example.txt", "a") as file:
    file.write("This line is appended.")

# %% [markdown]
# ### The CSV file
# > **Comma Separated Values** format is a common and straightforward way to store tabular data. To represent a CSV file, it should have the .csv file extension.

# %%
### Import the CSV module
import csv

# %% [markdown]
# > Write into CSV files with `csv.writer()`

# %%
# newline = creates an empty line between each line we write

with open('files/innovators.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["SN", "Name", "Contribution"])
    writer.writerow([1, "Linus Torvalds", "Linux Kernel"])
    writer.writerow([2, "Tim Berners-Lee", "World Wide Web"])
    writer.writerow([3, "Guido van Rossum", "Python Programming"])

# %% [markdown]
# > Writing Multiple Rows with `writerows()`

# %%
row_list = [["SN", "Name", "Contribution"],
             [1, "Linus Torvalds", "Linux Kernel"],
             [2, "Tim Berners-Lee", "World Wide Web"],
             [3, "Guido van Rossum", "Python Programming"]]
with open('files/protagonist.csv', 'w') as file:
    writer = csv.writer(file)
    writer.writerows(row_list)

# %% [markdown]
# ### **CSV Files with Custom Delimiters**
#
# >By default, a comma is used as a delimiter in a CSV file. However, some CSV files can use delimiters other than a comma. Few popular ones are `|` and `\t`.

# %%
data_list = [["SN", "Name", "Contribution"],
             [1, "Linus Torvalds", "Linux Kernel"],
             [2, "Tim Berners-Lee", "World Wide Web"],
             [3, "Guido van Rossum", "Python Programming"]]
with open('files/innovators_pipe_delimiter.csv', 'w', newline='') as file:
    writer = csv.writer(file, delimiter='|')
    writer.writerows(data_list)

# %% [markdown]
# > Read CSV files with `csv.reader()`

# %%
with open('files/innovators.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['SN', 'Name', 'Contribution']
# ['1', 'Linus Torvalds', 'Linux Kernel']
# ['2', 'Tim Berners-Lee', 'World Wide Web']
# ['3', 'Guido van Rossum', 'Python Programming']

# %% [markdown]
# > Read CSV files with `csv.DictReader()`

# %%
with open("files/people.csv", 'r') as file:
    csv_file = csv.DictReader(file)
    for row in csv_file:
        print(dict(row))
# Out:
# {'Name': 'Jack', 'Age': '23', 'Profession': 'Doctor'}
# {'Name': 'Miller', 'Age': '22', 'Profession': 'Engineer'}

# %% [markdown]
# ### JSON
#
# > **JavaScript Object Notation** is a popular data format used for representing structured data. It's common to transmit and receive data between a server and web application in JSON format.

# %%
# In Python, JSON exists as a string. For example:
p = '{"name": "Bob", "languages": ["Python", "Java"]}'

# %%
import json

# %% [markdown]
# > **Python JSON to dict**
# >
# > You can parse a JSON string using `json.loads()` method. The method returns a dictionary.

# %%
person = '{"name": "Bob", "languages": ["English", "French"]}'
person_dict = json.loads(person)
print(person_dict)
print('--' * 10)
print(person_dict['languages'])
# Out:
# {'name': 'Bob', 'languages': ['English', 'French']}
# --------------------
# ['English', 'French']

# %% [markdown]
# > **Python read JSON file**
# >
# > You can use `json.load()` method to read a file containing JSON object.

# %%
# Suppose, you have a file named person.json which contains a JSON object.

with open('files/person.json', 'r') as f:
  data = json.load(f)

print(data)
# Out:
# {'name': 'Bob', 'languages': ['English', 'French']}

# %% [markdown]
# > **Python Convert to JSON string**
# >
# > You can convert a dictionary to JSON string using `json.dumps()` method.

# %%
person_dict = {
    'name': 'Bob',
    'age': 12,
    'children': None
}
person_json = json.dumps(person_dict)
print(person_json)
# Out:
# {"name": "Bob", "age": 12, "children": null}

# %% [markdown]
# > **Writing JSON to a file**
# >
# > To write JSON to a file in Python, we can use `json.dump()` method.

# %%
person_dict = {"name": "Bob",
"languages": ["English", "French"],
"married": True,
"age": 32
}

with open('files/person_json.txt', 'w') as json_file:
  json.dump(person_dict, json_file)
