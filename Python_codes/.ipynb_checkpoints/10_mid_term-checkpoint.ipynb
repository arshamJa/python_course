# %% [markdown]
# ### Mid term exam

# %% [markdown]
# > Given Input: colours = ("red", "green", "blue"), replace "green" with "yellow"
# >
# > Expected Output:
# > Original: ('red', 'green', 'blue')
# > Modified: ('red', 'yellow', 'blue')

# %%
colours = ("red", "green", "blue")
print("Original:", colours)
temp = list(colours)
temp[1] = "yellow"
colours_modified = tuple(temp)
print("Modified:", colours_modified)
# Out:
# Original: ('red', 'green', 'blue')
# Modified: ('red', 'yellow', 'blue')

# %% [markdown]
# > Given Input:
# > A = {1, 2, 3, 4, 5, 6, 7, 8}
# >
# > B = {2, 4, 6}
# >
# > C = {5, 7, 9}
# >
# > Expected Output: Result: {1, 3, 8}

# %%
A = {1, 2, 3, 4, 5, 6, 7, 8}
B = {2, 4, 6}
C = {5, 7, 9}
result = A.difference(B, C)
print("Result:", result)
# Out:
# Result: {1, 3, 8}

# %% [markdown]
# > Unique Values Check:
# >
# > Given Input: data = {"a": 1, "b": 2, "c": 3, "d": 2}
# >
# > Expected Output: False

# %%
data = {"a": 1, "b": 2, "c": 3, "d": 2}
values = list(data.values())
is_unique = len(values) == len(set(values))
print(is_unique)
# Out:
# False

# %% [markdown]
# > Question: create a function that takes a list, uses list comprehension to:
# > * place all the 0 values into at the end of the list
# > * then order the list from the lowest to the highest value
# >
# > Given Input: List: [0, 1, 0, 3, 12]
# >
# > Expected Output: Result: [1, 3, 12, 0, 0]

# %%
def move_zeros(nums):
    # Filter non-zeros and zeros separately
    non_zeros = [x for x in nums if x != 0]
    zeros = [x for x in nums if x == 0]

    # Combine them
    return non_zeros + zeros

# Test the function
arr = [0, 1, 0, 3, 12]
result = move_zeros(arr)

print(f"Original: {arr}")
print(f"Zeros moved: {result}")
# Out:
# Original: [0, 1, 0, 3, 12]
# Zeros moved: [1, 3, 12, 0, 0]

# %% [markdown]
# ## Bonus Question:
# > Given a list of strings, use a single list comprehension to extract strings that meet two criteria:
# >
# > * they must be longer than 5 characters
# >
# > * they must start with a vowel (a, e, i, o, u).
# >
# > Given Input: ["apple", "education", "ice", "ocean", "python", "umbrella"]
# >
# > Expected Output: ['education', 'umbrella']

# %%
words = ["apple", "education", "ice", "ocean", "python", "umbrella"]

# Filter: starts with vowel AND length > 5
vowel_long = [
    w for w in words
    if len(w) > 5 and w[0].lower() in 'aeiou'
]

print(f"Original: {words}")
print(f"Filtered: {vowel_long}")
# Out:
# Original: ['apple', 'education', 'ice', 'ocean', 'python', 'umbrella']
# Filtered: ['education', 'umbrella']

# %% [markdown]
# ### itertools module
#
# The standard library itertools module has a collection of generators for many
# common data algorithms. For example, groupby takes any sequence and a function,
# grouping consecutive elements in the sequence by return value of the function. Here’s
# an example:
