# %% [markdown]
# ### This session we're going to cover:
# * While loop
# * Rock/paper/scissors mini project

# %%
https://www.geeksforgeeks.org/python/python-conditional-statement-and-loops-coding-problems/ 
this is a reference for practicing conditional
