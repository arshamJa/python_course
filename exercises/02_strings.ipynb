# %% [markdown]
# ### Challenge:
#
# > برنامه‌ای بنویسید که یک رشته جدید متشکل از اولین، میانی‌ترین و آخرین کاراکترهای یک رشته ورودی ایجاد کند
# >
# > Given Input: str1 = "James"
# >
# > Expected Output: Jms

# %% [markdown]
# ### Challenge:
#
# > برنامه‌ای برای معکوس کردن یک رشته بنویسید
# >
# > Given Input: str1 = "PYnative"
# >
# > Expected Output: evitanYP

# %% [markdown]
# ### Challenge:
#
# > Practice with several string methods (build a simple name formatter)
# >
# > full_name = "  john MICHAEL doe  "
#
# > Expected output:
#
#     Cleaned name: "   John Michael Doe  "
#     First name: John
#     Last name: Doe
#     Initials: JD
