# %% [markdown]
# ### Challenge:
#
# > برنامه‌ای به زبان پایتون بنویسید که یک تاپل ایجاد کند، از طریق اندیس به عناصر آن دسترسی پیدا کند و طول آن را بیابد
# >
# > Given Input: fruits = ("apple", "banana", "cherry", "date")
# >
# > Expected Output: First element: apple, Last element: date, and Length: 4

# %% [markdown]
# ### Challenge:
#
# > برنامه‌ای به زبان پایتون بنویسید که با استفاده از عملگر +، سه تاپل جداگانه را به یک تاپل جدید ترکیب کند
# >
# > Given Input: a = (1, 2), b = (3, 4), and c = (5, 6)
# >
# > Expected Output: (1, 2, 3, 4, 5, 6)

# %% [markdown]
# ### Challenge:
#
# > برنامه‌ای به زبان پایتون بنویسید که دو مجموعه را با هم ترکیب کرده و مجموعه‌ای شامل تمام عناصر یکتای هر دو مجموعه ایجاد کند
# >
# > Given Input: set_a = {1, 2, 3, 4} and set_b = {3, 4, 5, 6}
# >
# > Expected Output: Union: {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ### Challenge:
#
# > اما در هر دوی آنها حضور ندارند ،B یا در مجموعه   A برنامه‌ای به زبان پایتون بنویسید که تمام عناصری را پیدا کند که یا در مجموعه
# >
# >
# > Given Input: set_a = {1, 2, 3, 4} and set_b = {3, 4, 5, 6}
# >
# > Given Input: set_a = {1, 2, 3, 4} and set_b = {3, 4, 5, 6}
