# %% [markdown]
# ### Challenge:
# >max_speed و mileage: ایجاد کند (instance attribute)  با دو ویژگی نمونه Vehicle  یک برنامه پایتون بنویسید که کلاسی به نام
# >
# > سپس یک شیء از این کلاس بسازید و هر دو ویژگی را چاپ کنید
# >
# > Given Input: vehicle1 = Vehicle("Tesla Model S", 250, 18)
# >
# > Expected Output: Vehicle Name: Tesla Model S, Speed: 250, Mileage: 18

# %% [markdown]
# ### Challenge:
# > :یک برنامه پایتون بنویسید که یک کلاس مستطیل  با طول و عرض به عنوان ویژگی‌های نمونه و دو متد ایجاد کند
# >
# >که محیط را برمی‌گرداند perimeter() که مساحت و area()
# >
# > Given Input: rect = Rectangle(10, 4)
# >
# > Expected Output: Area = 40 and Perimeter = 28

# %% [markdown]
# ### Challenge:
# >ایجاد کند؛ این کلاس باید نام دانش‌آموز و فهرستی از نمرات او را ذخیره نماید `Student` یک برنامه پایتون بنویسید که کلاسی به نام
# >
# > به آن اضافه کنید که میانگین تمام نمرات را محاسبه کرده و برگرداند `average()` همچنین متدی به نام
# >
# > Given Input: s1 = Student("Alice", [85, 90, 78, 92, 88])
# >
# > Expected Output: Alice's Average Grade: 86.6

# %% [markdown]
# ### Challenge:
# > name، price و quantity :با سه ویژگی نمونه ایجاد کند Product یک برنامه پایتون بنویسید که یک کلاس
# >
# >بر‌گرداند quantity  در price اضافه کنید که ارزش کل موجودی را با ضرب total_value() یک متد
# >
# > Given Input: p1 = Product("Laptop", 899.99, 5)
# >
# > Expected Output: Total stock value of Laptop: $4499.95

# %% [markdown]
# ### Challenge:
# >:برای موجودی و دو متد باشد (attribute) ایجاد کند؛ این کلاس دارای یک ویژگی `BankAccount` یک برنامه پایتون بنویسید که کلاسی به نام
# >
# >که مبلغی را به موجودی اضافه می‌کند `deposit(amount)` متد
# >
# >که مبلغی را کسر می‌کند اما مانع از منفی شدن موجودی می‌شود`withdraw(amount)`  و متد
# >
# > Given Input: Starting balance of 1000, deposit 500, withdraw 200, then attempt to withdraw 2000.
# >
# > Expected Output:
#     Balance after deposit: 1500
#     Balance after withdrawal: 1300
#     Insufficient funds. Current balance: 1300

# %% [markdown]
# ### Challenge:
# >ایجاد کند و فهرستی داخلی از یادداشت‌ها را نگهداری نماید `Notebook` یک برنامه پایتون بنویسید که کلاسی به نام
# >
# >اضافه کنید که یادداشت جدیدی را به فهرست بیفزاید `add_note(note)`  متدی به نام
# >
# >که تمام یادداشت‌های ذخیره‌شده را چاپ کند`show_notes()` و همچنین متدی به نام
# >
# > Given Input: Add three notes: "Buy groceries", "Read a book", "Call the doctor".
# >
# > Expected Output:
#
#     1. Buy groceries
#     2. Read a book
#     3. Call the doctor
