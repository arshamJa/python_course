# %% [markdown]
# ### Challenge:
# > تابعی بنویسید که لیستی از اعداد را به عنوان ورودی دریافت کرده و بزرگ‌ترین عضو آن لیست را برگرداند
# >
# >انجام شود `max()`  این کار باید بدون استفاده از تابع داخلی
# >
# > Given Input: x = [4, 6, 8, 24, 12, 2]
# >
# > Expected Output: 24

# %% [markdown]
# ### Challenge:
#
# > تعریف کنید که توضیحی درباره یک حیوان خانگی چاپ کند`describe_pet(animal_type, pet_name)`  تابعی به نام
# >
# >(positional arguments) این تابع را دو بار فراخوانی کنید: یک بار با استفاده از آرگومان‌های موقعیتی
# >
# >(keyword arguments) و بار دیگر با استفاده از آرگومان‌های کلیدواژه‌ای
# >
# > Given Input:
# >
# > * Call 1 (Positional): "hamster", "Harry"
# >
# > * Call 2 (Keyword): animal_type="dog", pet_name="Willie"

# %% [markdown]
# ### Challenge
#
# >با مقدار ۱۰ تعریف کنید. تابعی بنویسید که مقدار این متغیر سراسری را با موفقیت به ۲۰ تغییر دهد. `global_var` یک متغیر سراسری به نام
# >
# >
# > Given Input: global_var = 10
# >
# > Expected Output:
# >
# > * Initial: 10
# >
# > * Modified: 20
