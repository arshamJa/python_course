# %% [markdown]
# ### Challenge:
#
# >: با داشتن فهرستی از اعداد، آن را پیمایش کنید و اعدادی را که این شرایط را برآورده می‌کنند، چاپ نمایید
# >
# > 1- آن عدد باید بر پنج بخش‌پذیر باشد
# >
# > 2- اگر عدد بزرگ‌تر از ۱۵۰ است، از آن رد شوید و به سراغ بعدی بروید
# >
# > 3- اگر عدد بزرگ‌تر از ۵۰۰ است، حلقه را به‌طور کامل متوقف کنید
# >
# > Done!
#
# > Given Input: numbers = [12, 75, 150, 180, 145, 525, 50]
#
# > Expected Output:
# >
# > 75
# >
# > 150
# >
# > 145

# %% [markdown]
# ### Challenge:
#
# > تعداد کل ارقام یک عدد صحیح داده شده را بشمارد while برنامه‌ای بنویسید که با استفاده از حلقه
# >
# > Given Input: 75869
# >
# > Expected Output: Total digits are: 5
