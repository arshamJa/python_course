# %% [markdown]
# ### Challenge:
#
# >را نمایش دهد (done) که از 0 تا 4 تکرار می شود پیام  for برنامه‌ای بنویسید که پس از اجرای موفقیت‌آمیز یک حلقه
# >
#
# Expected Output:
#
# 0
#
# 1
#
# 2
#
# 3
#
# 4
#
# Done!

# %% [markdown]
# ### Challenge:
#
# > را چاپ کند n را دریافت کرده و مکعب تمام اعداد از 1 تا n  برنامه‌ای بنویسید که یک عدد صحیح
# >
# > Given Input: input_number = 6
# >
#
# Expected Output:
#
# Current Number is : 1  and the cube is 1
#
# Current Number is : 2  and the cube is 8
#
# ...
#
# Current Number is : 6  and the cube is 216
