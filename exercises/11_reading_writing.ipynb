# %% [markdown]
# ### Challenge:
#
# >را بخواند و مجموع تعداد کلمات موجود در تمام سطرهای آن را بشمارد. data.txt  برنامه‌ای به زبان پایتون بنویسید که فایلی به نام
# >
# > Given Input: A file named data.txt containing:
#
#      Hello World
#      Python is great
#      File handling is easy
#
# > Expected Output: Total words: 9

# %% [markdown]
# ### Challenge:
# >را در آن بشمارد Python را بخواند و تعداد دفعات تکرار کلمه  data.txt برنامه‌ای به زبان پایتون بنویسید که فایل
# >
# > Given Input: A file named data.txt containing:
#
#     Python is great.
#     I love Python.
#     Python makes file handling easy.
#
# > Expected Output: Occurrences of 'Python': 3

# %% [markdown]
# ### Challenge:
# > را بخواند و چاپ کند data.txt  برنامه‌ای به زبان پایتون بنویسید که تنها ۳ خط اول فایل
# >
# > Given Input: A file named data.txt containing:
#
#     Line 1
#     Line 2
#     Line 3
#     Line 4
#     Line 5
# > Expected Output:
#
#     Line 1
#     Line 2
#     Line 3
