# %% [markdown]
# ### Challenge:
# > برنامه‌ای به زبان پایتون بنویسید که از کاربر بخواهد عددی را وارد کند
# >
# >ایجاد کنید و به‌جای متوقف شدن برنامه (کرش کردن)، پیام خطای مناسبی را نمایش دهید `ValueError` اگر ورودی یک عدد صحیح معتبر نباشد، یک
# >
# > Given Input: User enters "hello" when prompted for a number.
# >
# > Expected Output: Error: That was not a valid integer. Please enter a number.

# %% [markdown]
# ### Challenge:
# >برنامه‌ای بنویسید که سعی کند فایلی را که روی دیسک وجود ندارد، باز کند.
# >
# >در پایتون، پیامی واضح و کاربرپسند نمایش دهید (traceback)  را مدیریت کنید و به‌جای نمایش متن خام ردیابی خطا `FileNotFoundError` استثنای
# >
# > Given Input: Attempt to open "missing_file.txt" for reading.
# >
# > Expected Output: Error: The file 'missing_file.txt' was not found. Please check the filename and path.

# %% [markdown]
# ### Challenge:
# >تبدیل کرده (float) را به عدد اعشاری `value` بنویسید که مقدار `parse_and_divide(value, divisor)` تابعی به نام
# >
# >(خطای تبدیل) `ValueError`  واحد استفاده کنید که خطاهای  `try`  تقسیم کند از یک بلوک `divisor`  و سپس آن را بر
# >
# > را مدیریت کرده و برای هر یک پیام جداگانه‌ای نمایش دهد `ZeroDivisionError` (تقسیم بر صفر) و
# >
# > Given Input: Call parse_and_divide("abc", 2) and parse_and_divide("10", 0) and parse_and_divide("10", 2).
# >
# > Expected Output:
#
#     Error: 'abc' cannot be converted to a number.
#     Error: Cannot divide by zero.
#     5.0
