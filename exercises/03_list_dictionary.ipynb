# %% [markdown]
# ### Challenge:
#
# > تعداد دفعات تکرار یک مقدار مشخص در یک لیست را پیدا کنید
# >
# > Given Input:
# > List: [10, 20, 30, 10, 40, 10, 50]
# >
# > Target: 10
# >
# > Expected Output: The number 10 appears 3 times.

# %% [markdown]
# ### Challenge:
#
# > افزودن مورد جدید پس از یک مورد مشخص
# >
# > Given Input:
# >
# >List: [10, 20, 30, 40, 50]
# >
# >Insert after: 30
# >
# >New Item: 35
# >
# >Expected Output: Updated List: [10, 20, 30, 35, 40, 50]

# %% [markdown]
# ### Challenge:
#
# > برنامه‌ای به زبان پایتون بنویسید که یک جفت کلید-مقدار جدید به یک دیکشنری اضافه کند، مقدار موجودی را تغییر دهد و به کلید خاصی دسترسی پیدا کند
# >
# > Given Input: student = {"name": "Alice", "age": 20, "grade": "B"}
# >
# >Expected Output: {"name": "Alice", "age": 21, "grade": "B", "city": "New York"} and Name: Alice

# %% [markdown]
# ### Challenge:
#
# > برنامه‌ای به زبان پایتون بنویسید که مقدار مرتبط با کلید را از یک دیکشنریِ تو‌در‌تو (که درون یک ساختار داده‌ای بزرگ‌تر قرار دارد) استخراج کند.
# >
# > Given Input: student = {"name": "Dave", "grades": {"math": 88, "science": 92, "history": 75}}
# >
# > Expected Output: History grade: 75
